# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('computer_parts_prices_dirty.csv')
df.head()
# Out:
#    Processor       GPU      RAM  Storage      PSU  Motherboard     Total
# 0    55795.0  138953.0  37174.0  72623.0   9931.0      35932.0  350408.0
# 1    40860.0  112995.0  10454.0  32299.0      NaN      44855.0       NaN
# 2   116820.0  231829.0  19837.0  53585.0   5202.0      22158.0  449431.0
# 3    94886.0   69692.0  22039.0  74044.0  16447.0      58016.0  335124.0
# 4    46265.0  236830.0  33380.0  52557.0  17688.0      22400.0  409120.0

# %%
df.columns = ['col1', 'col2','col3', 'col4','col5', 'col6','col7']
df.head()
# Out:
#        col1      col2     col3     col4          col5     col6           col7
# 0   55795.0  138953.0  37174.0  72623.0   9931.000000  35932.0  350408.000000
# 1   40860.0  112995.0  10454.0  32299.0  14558.645833  44855.0  340656.947368
# 2  116820.0  231829.0  19837.0  53585.0   5202.000000  22158.0  449431.000000
# 3   94886.0   69692.0  22039.0  74044.0  16447.000000  58016.0  335124.000000
# 4   46265.0  236830.0  33380.0  52557.0  17688.000000  22400.0  409120.000000

# %%
df.isnull().sum()
# Out:
# col1    0
# col2    0
# col3    0
# col4    0
# col5    0
# col6    0
# col7    0
# dtype: int64

# %%
mean_value = df["col1"].mean()
df["col1"] = df["col1"].fillna(mean_value)

mean_value = df["col2"].mean()
df["col2"] = df["col2"].fillna(mean_value)

mean_value = df["col3"].mean()
df["col3"] = df["col3"].fillna(mean_value)

mean_value = df["col4"].mean()
df["col4"] = df["col4"].fillna(mean_value)

mean_value = df["col5"].mean()
df["col5"] = df["col5"].fillna(mean_value)

mean_value = df["col6"].mean()
df["col6"] = df["col6"].fillna(mean_value)

mean_value = df["col7"].mean()
df["col7"] = df["col7"].fillna(mean_value)

# %%
df.isnull().sum()
# Out:
# col1    0
# col2    0
# col3    0
# col4    0
# col5    0
# col6    0
# col7    0
# dtype: int64

# %%
df.drop_duplicates (inplace=True)

# %%
df.columns = df.columns.str.lower()

# %%
#Features & target
x= df[['col1', 'col2', 'col3', 'col4', 'col5', 'col6']]
y = df['col7']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
y_test
# Out:
# 13    302995.000000
# 39    340656.947368
# 30    423777.000000
# 45    340656.947368
# 17    325374.000000
# 48    340656.947368
# 26    243590.000000
# 25    294311.000000
# 32    367741.000000
# 19    340656.947368
# Name: col7, dtype: float64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([305713.78962793, 397465.36174632, 397194.42763724, 235638.66653569,
#        325538.03391961, 345423.38017166, 262174.68649327, 313447.57928205,
#        382289.58930002, 441044.79061273])

# %%
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

threshold = 100000
if mae <= threshold:
    print("Better Model ✅")
else:
    print("Bad Model ❌")
# Out:
# Mean Absolute Error (MAE): 34871.62222438221
# Better Model ✅

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

threshold = 100000
if mae <= threshold:
    print("Better Model ✅")
else:
    print("Bad Model ❌")
# Out:
# Mean Squared Error (MSE): 2599378577.2987914
# Better Model ✅

# %%
r2 = r2_score(y_test, y_pred)
print("R² Score (Coefficient of Determination):", r2)

threshold = 100000
if mae <= threshold:
    print("Better Model ✅")
else:
    print("Bad Model ❌")
# Out:
# R² Score (Coefficient of Determination): -0.29179813339520866
# Better Model ✅

# %%
new_pc = [[55795, 138953, 37174, 72623	, 9931, 35932]]
predicted_price = model.predict(new_pc)

print("Predicted Total Price:", predicted_price[0])
# Out:
# Predicted Total Price: 359326.7830079753
# C:\Users\PC\anaconda3\ana\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
